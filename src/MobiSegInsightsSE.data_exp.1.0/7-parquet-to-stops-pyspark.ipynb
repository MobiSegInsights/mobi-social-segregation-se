# %% [markdown]
# # Use Pyspark for data processing
# The raw data contain ca. 4.6 billion rows. The processing is to detect stops by individual.

# %%
# %load_ext autoreload
# %autoreload 2
# %cd D:\mobi-social-segregation-se
# Out:
# D:\mobi-social-segregation-se

# %%
# Load libs
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
from pyspark.sql import SparkSession
import sys
import pyspark.sql.functions as F
from pyspark.sql.types import *
from pyspark import SparkConf
from infostop import Infostop
import sqlalchemy
from lib import preprocess as preprocess
import time
import matplotlib.pyplot as plt
import folium
import seaborn as sns

# %%
# Data location
user = preprocess.keys_manager['database']['user']
password = preprocess.keys_manager['database']['password']
port = preprocess.keys_manager['database']['port']
db_name = preprocess.keys_manager['database']['name']
engine = sqlalchemy.create_engine(f'postgresql://{user}:{password}@localhost:{port}/{db_name}')

# %%
# Set up pyspark
os.environ['PYSPARK_PYTHON'] = sys.executable
os.environ['PYSPARK_DRIVER_PYTHON'] = sys.executable
# Create new context
spark_conf = SparkConf().setMaster("local[18]").setAppName("MobiSeg")
spark_conf.set("spark.executor.heartbeatInterval","3600s")
spark_conf.set("spark.network.timeout","7200s")
spark_conf.set("spark.sql.files.ignoreCorruptFiles","true")
spark_conf.set("spark.driver.memory", "40g")
spark_conf.set("spark.executor.memory","8g")
spark_conf.set("spark.memory.fraction", "0.6")
spark_conf.set("spark.sql.session.timeZone", "UTC")
spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()
print('Web UI:', spark.sparkContext.uiWebUrl)
# Out:
# Web UI: http://C19YUEI.net.chalmers.se:4040

# %%
# infostop function
# R1, R2, MIN_STAY, MAX_TIME_BETWEEN = 30, 30, 15, 4  # meters, meters, minutes, hours
def infostop_per_user(key, data):
    model = Infostop(
        r1=R1,
        r2=R2,
        label_singleton=True,
        min_staying_time=MIN_STAY*60,
        max_time_between=MAX_TIME_BETWEEN*60*60,
        min_size=2,
        min_spacial_resolution=0,
        distance_metric='haversine',
        weighted=False,
        weight_exponent=1,
        verbose=False,)
    x = data.loc[~(((data['latitude'] > 84) | (data['latitude'] < -80)) | ((data['longitude'] > 180) | (data['longitude'] < -180))), :]
    x = x.sort_values(by='timestamp').drop_duplicates(subset=['latitude','longitude','timestamp']).reset_index(drop=True)
    x = x.dropna()
    ##THE THING RECORDS A POINT EVERYTIME THE ACCELEROMETER REGISTER A CHANGE, SO ASSUME NO MOVE UP TO 12 hours
    x['t_seg'] = x['timestamp'].shift(-1)
    x.loc[x.index[-1],'t_seg'] = x.loc[x.index[-1],'timestamp']+1
    x['n'] = x.apply(lambda x: range(int(x['timestamp']),
                                     min(int(x['t_seg']), x['timestamp']+(MAX_TIME_BETWEEN*60*60)),
                                     (MAX_TIME_BETWEEN*60*60-1)),axis=1)
    x = x.explode('n')
    x['timestamp'] = x['n'].astype(float)
    x = x[['latitude','longitude','timestamp']].dropna() # ,'timezone'

    try:
        labels = model.fit_predict(x[['latitude','longitude','timestamp']].values)
    except:
        return pd.DataFrame([],columns=['device_aid','timestamp','latitude','longitude','loc','stop_latitude','stop_longitude','interval']) #,'timezone'

    label_medians = model.compute_label_medians()
    x['loc'] = labels
    x['same_loc'] = x['loc']==x['loc'].shift()
    # x['same_timezone'] = x['timezone']==x['timezone'].shift()
    x['little_time'] = (x['timestamp'] - x['timestamp'].shift() < MAX_TIME_BETWEEN*60*60)

    x['interval'] = (~( x['same_loc'] &
                        x['little_time'])).cumsum() # & x['same_timezone']

    latitudes = {k:v[0] for k,v in label_medians.items()}
    longitudes = {k:v[1] for k,v in label_medians.items()}
    x['stop_latitude'] = x['loc'].map(latitudes)
    x['stop_longitude'] = x['loc'].map(longitudes)
    x['device_aid'] = key[0]

    #keep only stop locations
    x = x[x['loc']>0].copy()

    return x[['device_aid','timestamp','latitude','longitude','loc','stop_latitude','stop_longitude','interval']] #,'timezone'

schema = StructType([StructField('loc',IntegerType()),
                     StructField('timestamp',IntegerType()),
                     StructField('interval',IntegerType()),
                     StructField('latitude',DoubleType()),
                     StructField('longitude',DoubleType()),
                     StructField('device_aid',StringType()),
                     StructField('stop_latitude',DoubleType()),
                     StructField('stop_longitude',DoubleType()),
                    ]) # StructField('timezone',IntegerType()),

# %% [markdown]
# .parquet data files

# %%
data_folder = 'D:\\MAD_dbs\\raw_data_se_2019\\format_parquet'
paths = [x[0] for x in os.walk(data_folder)]
paths = paths[1:]
file_paths_list = []
for path in paths:
    files = os.listdir(path)
    file_paths = [os.path.join(path, f) for f in files]
    file_paths_list.append(file_paths)  # 100 groups of users

# %% [markdown]
# Define schema

# %%
customSchema = StructType([
    StructField("timestamp", IntegerType(), True),
    StructField('device_aid', StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("utm_x", DoubleType(), True),
    StructField("utm_y", DoubleType(), True)
])

# %% [markdown]
# ## 1. Explore the delta values distributions of time, UTM_x, UTM_y, and displacement

# %%
# Take first group of users' data
df = spark.read.parquet(*file_paths_list[0])
df.rdd.getNumPartitions()
# Out:
# 18

# %%
# Compute the statistics
def delta_stats(data):
    x = data.loc[~(((data['latitude'] > 84) | (data['latitude'] < -80)) | ((data['longitude'] > 180) | (data['longitude'] < -180))), :]
    x = x.sort_values(by='timestamp')
    for var, var_name in zip(('utm_x', 'utm_y', 'timestamp'), ('xDelta', 'yDelta', 'tDelta')):
        x.loc[:, var_name] = x.loc[:, var].diff()
    x = x[['device_aid', 'timestamp', 'xDelta', 'yDelta', 'tDelta']].dropna()
    x.loc[:, 'displacement'] = (x.loc[:, 'xDelta']**2 + x.loc[:, 'yDelta']**2)**0.5
    return x
## Find delta stats
schema_stats = StructType([
    StructField('device_aid', StringType(), True),
    StructField("timestamp", IntegerType(), True),
    StructField("xDelta", DoubleType(), True),
    StructField("yDelta", DoubleType(), True),
    StructField("tDelta", IntegerType(), True),
    StructField('displacement', DoubleType(), True)
])
df_delta = df.groupby('device_aid').applyInPandas(delta_stats, schema=schema_stats)
df_delta.show(5)
# Out:
# +--------------------+----------+------------------+-------------------+------+------------------+
# |          device_aid| timestamp|            xDelta|             yDelta|tDelta|      displacement|
# +--------------------+----------+------------------+-------------------+------+------------------+
# |0034e0de-6142-410...|1565045890|105.32860225334298|-2.0714687695726752|     5|105.34896978853776|
# |0034e0de-6142-410...|1565045895|101.54553620098159|-1.9546708408743143|     5|101.56434738844644|
# |0034e0de-6142-410...|1565045900| 94.71067110006697| 1.5948922615498304|     5| 94.72409884264412|
# |0034e0de-6142-410...|1565045905| 90.99458196188789|  3.936294407583773|     5|  91.0796813788998|
# |0034e0de-6142-410...|1565045910| 89.69978489552159| 2.8635651702061296|     5| 89.74548131124408|
# +--------------------+----------+------------------+-------------------+------+------------------+
# only showing top 5 rows

# %%
# Convert to pandas data frame and subset 10,000 rows
df_delta = df_delta.toPandas()
df_delta = df_delta.sample(n=10000)

# %% [markdown]
# ### 1.1 Distributions
# #### 1.1.1 Time gaps

# %%
fig, ax = plt.subplots()
bin_counts, bin_edges, patches = plt.hist(df_delta.loc[df_delta['tDelta'] > 0, 'tDelta'],
         bins = [10**(x/10) for x in range(0, 80)], color=['orange'], ec="blue", alpha=0.5)
bin_centres = (bin_edges[:-1] + bin_edges[1:]) / 2
# plt.errorbar(x=bin_centres, y=bin_counts, fmt='o', capsize=2)
plt.axvline(15*60)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Delta T (sec)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### 1.1.2 Displacement gaps

# %%
fig, ax = plt.subplots()
plt.hist(df_delta.loc[df_delta['displacement'] > 0, 'displacement'],
         bins = [10**(x/10) for x in range(0, 70)], color=['orange'], ec="blue", alpha=0.5)
plt.axvline(30)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Delta distance (m)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 2. Selecting infostop algorithm parameters

# %%
def infostop_detection_test():
    grp = 0
    df = spark.read.parquet(*file_paths_list[grp]).\
        select('device_aid', 'timestamp', 'latitude', 'longitude')
    stops = df.groupby('device_aid').applyInPandas(infostop_per_user, schema=schema)
    stop_locations = stops.groupby('device_aid','interval').agg(F.first('loc').alias('loc'),
                          F.min('timestamp').alias('start'),
                          F.max('timestamp').alias('end'),
                          F.first('stop_latitude').alias('latitude'),
                          F.first('stop_longitude').alias('longitude'),
                          F.count('loc').alias('size'))
    df_stops = stop_locations.toPandas()
    df_stops.loc[:, 'dur'] = (df_stops['end'] - df_stops['start']) / 60 # minute
    df_stops.loc[:, 'sampling_freq'] = df_stops.loc[:, 'size'] / (df_stops.loc[:, 'dur'] / 60) # location / hour
    return df_stops

def stops_stats(data, thre):
    dur_min = data['dur'].min()
    dur_max = data['dur'].max()
    dur_med = data['dur'].median()
    dur_thre = len(data.loc[data['dur'] >= thre * 60, :]) / len(data)

    sfre_min = data['sampling_freq'].min()
    sfre_max = data['sampling_freq'].max()
    sfre_med = data['sampling_freq'].median()
    sfre_one = len(data.loc[data['sampling_freq'] >= 1, :]) / len(data)
    return dict(dur_min=dur_min, dur_max=dur_max, dur_med=dur_med, dur_thre=dur_thre,
                sfre_min=sfre_min, sfre_max=sfre_max, sfre_med=sfre_med, sfre_one=sfre_one)

# %% [markdown]
# ### 2.0 Distributions of stay duration and average sampling frequency (# of points / hour per detected stay)

# %%
# R1, R2, MIN_STAY, MAX_TIME_BETWEEN = 30, 30, 15, 4  # meters, meters, minutes, hours
paraset = [(30, 30, 15, x) for x in range(1, 13)]
stats_df_list = []
for para in tqdm(paraset, desc='Compute different parameters'):
    R1, R2, MIN_STAY, MAX_TIME_BETWEEN = para[0], para[1], para[2], para[3]  # meters, meters, minutes, hours
    df_stops = infostop_detection_test()
    dc = stops_stats(data=df_stops, thre=para[3])
    dc['max_time_between'] = para[3]
    stats_df_list.append(dc)
df_stops_stats = pd.DataFrame(stats_df_list)
df_stops_stats.head()
# Out:
# Compute different parameters: 100%|██████████| 12/12 [19:15<00:00, 96.29s/it]
#    dur_min       dur_max     dur_med  dur_thre  sfre_min    sfre_max  \
# 0     15.0  23519.900000   64.883333  0.717017  1.118360  723.809524
# 1     15.0  31810.883333  124.350000  0.679778  0.610463  723.809524
# 2     15.0  36169.633333  183.333333  0.646321  0.400705  723.809524
# 3     15.0  44580.150000  242.516667  0.619992  0.308748  723.809524
# 4     15.0  44580.150000  301.833333  0.596501  0.256183  723.809524
#
#    sfre_med  sfre_one  max_time_between
# 0  5.309735  1.000000                 1
# 1  3.923706  0.982465                 2
# 2  3.336128  0.772716                 3
# 3  3.053535  0.742608                 4
# 4  2.839490  0.721737                 5

# %%
fig, ax = plt.subplots()
plt.scatter(x=df_stops_stats['max_time_between'], y=df_stops_stats['dur_thre'], c='red', label='Duration above the max time between')
plt.scatter(x=df_stops_stats['max_time_between'], y=df_stops_stats['sfre_one'], c='blue', label='Average sampling frequency above 1 / hr')
plt.legend()
plt.xlabel("Max time between (hr)")
plt.ylabel("Share of stays")
plt.show()

# %%
R1, R2, MIN_STAY, MAX_TIME_BETWEEN = 30, 30, 15, 3  # meters, meters, minutes, hours
df_stops = infostop_detection_test()

# %%
fig, ax = plt.subplots()
plt.hist(df_stops['dur'],
         bins = [10**(x/10) for x in range(10, 50)], color=['orange'], ec="blue", alpha=0.5)
plt.axvline(3*60)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Stay length (min)")
plt.ylabel("Frequency")
plt.show()

# %%
fig, ax = plt.subplots()
plt.hist(df_stops['sampling_freq'],
         bins = [10**x for x in np.linspace(np.log10(df_stops['sampling_freq'].min()),
                                                 np.log10(df_stops['sampling_freq'].max()),
                                                 50)], color=['orange'], ec="blue", alpha=0.5)
plt.axvline(1)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("# of records / hour")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### 2.1 Select two example devices

# %%
df_devices = df_stops.groupby('device_aid')['size'].count().sort_values(ascending=False).reset_index()
device = df_devices.loc[(df_devices['size'] > 10) & (df_devices['size'] < 20), 'device_aid'].values[89]

# %% [markdown]
# ### 2.2 Get the raw data of a given device

# %%
df_eg = df.filter(F.col('device_aid')==device).toPandas().sort_values(by='timestamp')
df_eg.loc[:, 'stop_id'] = 0

# %%
df_eg_stops = df_stops.loc[df_stops['device_aid']==device, :].sort_values(by='start')
df_eg_stops.loc[:, 'stop_id'] = range(1, len(df_eg_stops) + 1)

# %%
for _, row in df_eg_stops.iterrows():
    df_eg.loc[(df_eg['timestamp'] <= row['end']) & (df_eg['timestamp'] >= row['start']), 'stop_id'] = row['stop_id']

# %%
df_eg.head()
# Out:
#                               device_aid   timestamp  latitude  longitude  \
# 14  0a1be937-076a-4ae3-8ee4-17c37bf46731  1575398042     57.32      12.19
# 13  0a1be937-076a-4ae3-8ee4-17c37bf46731  1575398112     57.32      12.19
# 17  0a1be937-076a-4ae3-8ee4-17c37bf46731  1575398132     57.32      12.19
# 16  0a1be937-076a-4ae3-8ee4-17c37bf46731  1575398232     57.32      12.19
# 15  0a1be937-076a-4ae3-8ee4-17c37bf46731  1575398274     57.32      12.19
#
#     stop_id
# 14        1
# 13        1
# 17        1
# 16        1
# 15        1

# %% [markdown]
# ### 2.3 Show all the data

# %%
colors = {x:y for x, y in zip(df_eg.stop_id.unique(), sns.color_palette("plasma", df_eg.stop_id.nunique()).as_hex())}
map_osm = folium.Map(location=df_eg[['latitude', 'longitude']].values[0])
df_eg.apply(lambda row : folium.CircleMarker(location=(row["latitude"], row["longitude"]),
                                             radius=3, fill_color=colors[row['stop_id']], popup=row['stop_id'],
                                             color=colors[row['stop_id']]).add_to(map_osm), axis=1)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e54f6d4712955a30df81a2124d16c7da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e54f6d4712955a30df81a2124d16c7da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e54f6d4712955a30df81a2124d16c7da = L.map(
#                 &quot;map_e54f6d4712955a30df81a2124d16c7da&quot;,
#                 {
#                     center: [57.32, 12.19],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7dc1656762a1fbed3d5d4a98f96c782 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e54f6d4712955a30df81a2124d16c7da);
#
#
#             var circle_marker_87d4d55daee18257f46a0c51f6a198cd = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e54f6d4712955a30df81a2124d16c7da);
#
#
#         var popup_e0efc760b3beb5ac6ef843aba53e3314 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_fc68193e8a8a882a0fac629192381243 = $(`&lt;div id=&quot;html_fc68193e8a8a882a0fac629192381243&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_e0efc760b3beb5ac6ef843aba53e3314.setContent(html_fc68193e8a8a882a0fac629192381243);
#
#
#         circle_marker_87d4d55daee18257f46a0c51f6a198cd.bindPopup(popup_e0efc760b3beb5ac6ef843aba53e3314)
#         ;
#
#
#
#
#             var circle_marker_518ce4744829bfa34d742ab753554aec = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e54f6d4712955a30df81a2124d16c7da);
#
#
#         var popup_1d0ce702c1664ea5f76318c9dba3b249 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_134e6294cefd5b7acad6d5f2e273693a = $(`&lt;div id=&quot;html_134e6294cefd5b7acad6d5f2e273693a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_1d0ce702c1664ea5f76318c9dba3b249.setContent(html_134e6294cefd5b7acad6d5f2e273693a);
#
#
#         circle_marker_518ce4744829bfa34d742ab753554aec.bindPopup(popup_1d0ce702c1664ea5f76318c9dba3b249)
#         ;
#
#
#
#
#             var circle_marker_33b1e6c9fd8c02344de1b8f21cfdf68b = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e54f6d4712955a30df81a2124d16c7da);
#
#
#         var popup_fa21864422dde741f8c298deaecce67d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_956aa3746ae7f294d041984c4b353ed6 = $(`&lt;div id=&quot;html_956aa3746ae7f294d041984c4b353ed6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_fa21864422dde741f8c298deaecce67d.setContent(html_956aa3746ae7f294d041984c4b353ed6);
#
#
#         circle_marker_33b1e6c9fd8c02344de1b8f21cfdf68b.bindPopup(popup_fa21864422dde741f8c298deaecce67d)
#         ;
#
#
#
#
#             var circle_marker_6558f4feff068049da75a20b75e9d23c = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;w

# %% [markdown]
# ### 2.4 Show only stays

# %%
df_eg_s = df_eg.loc[df_eg.stop_id > 0, :]
colors = {x:y for x, y in zip(df_eg_s.stop_id.unique(), sns.color_palette("plasma", df_eg_s.stop_id.nunique()).as_hex())}
map_osm = folium.Map(location=df_eg_s[['latitude', 'longitude']].values[0], zoom_start=11)
df_eg_s.apply(lambda row : folium.CircleMarker(location=(row["latitude"], row["longitude"]),
                                             radius=3, fill_color=colors[row['stop_id']], popup=row['stop_id'],
                                             color=colors[row['stop_id']]).add_to(map_osm), axis=1)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0b34eaf3e28fbc6f638e55034f5e727 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0b34eaf3e28fbc6f638e55034f5e727&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0b34eaf3e28fbc6f638e55034f5e727 = L.map(
#                 &quot;map_d0b34eaf3e28fbc6f638e55034f5e727&quot;,
#                 {
#                     center: [57.32, 12.19],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b19729b399e70f9c1395a480e5253dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d0b34eaf3e28fbc6f638e55034f5e727);
#
#
#             var circle_marker_fb61e5196ce9ca027d08c0bec4a0a3fe = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0b34eaf3e28fbc6f638e55034f5e727);
#
#
#         var popup_6ebca4a94ee6a43379cb7ce4d56d7624 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_99882151e206bb27aae93cf342fee40c = $(`&lt;div id=&quot;html_99882151e206bb27aae93cf342fee40c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_6ebca4a94ee6a43379cb7ce4d56d7624.setContent(html_99882151e206bb27aae93cf342fee40c);
#
#
#         circle_marker_fb61e5196ce9ca027d08c0bec4a0a3fe.bindPopup(popup_6ebca4a94ee6a43379cb7ce4d56d7624)
#         ;
#
#
#
#
#             var circle_marker_7c10f340a5bb38a1907bdf8fb5c19c75 = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0b34eaf3e28fbc6f638e55034f5e727);
#
#
#         var popup_035ec3d30c3555030123235cc780d9f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b6950a60080ee26d9e32f4f805caa425 = $(`&lt;div id=&quot;html_b6950a60080ee26d9e32f4f805caa425&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_035ec3d30c3555030123235cc780d9f9.setContent(html_b6950a60080ee26d9e32f4f805caa425);
#
#
#         circle_marker_7c10f340a5bb38a1907bdf8fb5c19c75.bindPopup(popup_035ec3d30c3555030123235cc780d9f9)
#         ;
#
#
#
#
#             var circle_marker_791cbdf361a659c371e77f91d9e7d8e6 = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d0b34eaf3e28fbc6f638e55034f5e727);
#
#
#         var popup_92a52ec07576bed605938a8257745d77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0192d8cb149aa805e3d8f932f0c7640c = $(`&lt;div id=&quot;html_0192d8cb149aa805e3d8f932f0c7640c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1&lt;/div&gt;`)[0];
#             popup_92a52ec07576bed605938a8257745d77.setContent(html_0192d8cb149aa805e3d8f932f0c7640c);
#
#
#         circle_marker_791cbdf361a659c371e77f91d9e7d8e6.bindPopup(popup_92a52ec07576bed605938a8257745d77)
#         ;
#
#
#
#
#             var circle_marker_0119cf7d1de13ac8f8b8b3cfcbba1885 = L.circleMarker(
#                 [57.32, 12.19],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2a0593&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#2a0593&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;w

# %% [markdown]
# ## 3. Run infostop algorithm to detect stays

# %%
R1, R2, MIN_STAY, MAX_TIME_BETWEEN = 30, 30, 15, 3  # meters, meters, minutes, hours
for file_paths, grp in zip(file_paths_list, range(0, 100)):
    print(f'Processing user group {grp}:')
    start = time.time()
    df = spark.read.parquet(*file_paths).\
        select('device_aid', 'timestamp', 'latitude', 'longitude')
    stops = df.groupby('device_aid').applyInPandas(infostop_per_user, schema=schema)
    stop_locations = stops.groupby('device_aid','interval').agg(F.first('loc').alias('loc'),
                          F.min('timestamp').alias('start'),
                          F.max('timestamp').alias('end'),
                          F.first('stop_latitude').alias('latitude'),
                          F.first('stop_longitude').alias('longitude'),
                          F.count('loc').alias('size'))
    df_stops = stop_locations.toPandas()
    # Save data to database
    print("Saving data...")
    df_stops.to_sql('stops_r', engine, schema='public', index=False, if_exists='append',
                    method='multi', chunksize=5000)
    end = time.time()
    time_elapsed = (end - start)//60 #  in minutes
    print(f"Group {grp} processed and saved in {time_elapsed} minutes.")
# Out:
# Processing user group 0:
# Saving data...
# Group 0 processed and saved in 2.0 minutes.
# Processing user group 1:
# Saving data...
# Group 1 processed and saved in 2.0 minutes.
# Processing user group 2:
# Saving data...
# Group 2 processed and saved in 2.0 minutes.
# Processing user group 3:
# Saving data...
# Group 3 processed and saved in 2.0 minutes.
# Processing user group 4:
# Saving data...
# Group 4 processed and saved in 2.0 minutes.
# Processing user group 5:
# Saving data...
# Group 5 processed and saved in 2.0 minutes.
# Processing user group 6:
# Saving data...
# Group 6 processed and saved in 2.0 minutes.
# Processing user group 7:
# Saving data...
# Group 7 processed and saved in 2.0 minutes.
# Processing user group 8:
# Saving data...
# Group 8 processed and saved in 2.0 minutes.
# Processing user group 9:
# Saving data...
# Group 9 processed and saved in 2.0 minutes.
# Processing user group 10:
# Saving data...
# Group 10 processed and saved in 2.0 minutes.
# Processing user group 11:
# Saving data...
# Group 11 processed and saved in 2.0 minutes.
# Processing user group 12:
# Saving data...
# Group 12 processed and saved in 2.0 minutes.
# Processing user group 13:
# Saving data...
# Group 13 processed and saved in 2.0 minutes.
# Processing user group 14:
# Saving data...
# Group 14 processed and saved in 2.0 minutes.
# Processing user group 15:
# Saving data...
# Group 15 processed and saved in 2.0 minutes.
# Processing user group 16:
# Saving data...
# Group 16 processed and saved in 2.0 minutes.
# Processing user group 17:
# Saving data...
# Group 17 processed and saved in 2.0 minutes.
# Processing user group 18:
# Saving data...
# Group 18 processed and saved in 2.0 minutes.
# Processing user group 19:
# Saving data...
# Group 19 processed and saved in 2.0 minutes.
# Processing user group 20:
# Saving data...
# Group 20 processed and saved in 2.0 minutes.
# Processing user group 21:
# Saving data...
# Group 21 processed and saved in 2.0 minutes.
# Processing user group 22:
# Saving data...
# Group 22 processed and saved in 2.0 minutes.
# Processing user group 23:
# Saving data...
# Group 23 processed and saved in 2.0 minutes.
# Processing user group 24:
# Saving data...
# Group 24 processed and saved in 2.0 minutes.
# Processing user group 25:
# Saving data...
# Group 25 processed and saved in 2.0 minutes.
# Processing user group 26:
# Saving data...
# Group 26 processed and saved in 2.0 minutes.
# Processing user group 27:
# Saving data...
# Group 27 processed and saved in 2.0 minutes.
# Processing user group 28:
# Saving data...
# Group 28 processed and saved in 2.0 minutes.
# Processing user group 29:
# Saving data...
# Group 29 processed and saved in 2.0 minutes.
# Processing user group 30:
# Saving data...
# Group 30 processed and saved in 2.0 minutes.
# Processing user group 31:
# Saving data...
# Group 31 processed and saved in 2.0 minutes.
# Processing user group 32:
# Saving data...
# Group 32 processed and saved in 2.0 minutes.
# Processing user group 33:
# Saving data...
# Group 33 processed and saved in 2.0 minutes.
# Processing user group 34:
# Saving data...
# Group 34 processed and saved in 2.0 minutes.
# Processing user group 35:
# Saving data...
# Group 35 processed and saved in 2.0 minutes.
# Processing user group 36:
# Saving data...
# Group 36 processed and saved in 2.0 minutes.
# Processing user group 37:
# Saving data...
# Group 37 processed and saved in 2.0 minutes.
# Processing user group 38:
# Saving data...
# Group 38 processed and saved in 2.0 minutes.
# Processing user group 39:
# Saving data...
# Group 39 processed and saved in 2.0 minutes.
# Processing user group 40:
# Saving data...
# Group 40 processed and saved in 2.0 minutes.
# Processing user group 41:
# Saving data...
# Group 41 processed and saved in 2.0 minutes.
# Processing user group 42:
# Saving data...
# Group 42 processed and saved in 2.0 minutes.
# Processing user group 43:
# Saving data...
# Group 43 processed and saved in 2.0 minutes.
# Processing user group 44:
# Saving data...
# Group 44 processed and saved in 2.0 minutes.
# Processing user group 45:
# Saving data...
# Group 45 processed and saved in 2.0 minutes.
# Processing user group 46:
# Saving data...
# Group 46 processed and saved in 2.0 minutes.
# Processing user group 47:
# Saving data...
# Group 47 processed and saved in 2.0 minutes.
# Processing user group 48:
# Saving data...
# Group 48 processed and saved in 2.0 minutes.
# Processing user group 49:
# Saving data...
# Group 49 processed and saved in 2.0 minutes.
# Processing user group 50:
# Saving data...
# Group 50 processed and saved in 2.0 minutes.
# Processing user group 51:
# Saving data...
# Group 51 processed and saved in 2.0 minutes.
# Processing user group 52:
# Saving data...
# Group 52 processed and saved in 2.0 minutes.
# Processing user group 53:
# Saving data...
# Group 53 processed and saved in 2.0 minutes.
# Processing user group 54:
# Saving data...
# Group 54 processed and saved in 2.0 minutes.
# Processing user group 55:
# Saving data...
# Group 55 processed and saved in 2.0 minutes.
# Processing user group 56:
# Saving data...
# Group 56 processed and saved in 2.0 minutes.
# Processing user group 57:
# Saving data...
# Group 57 processed and saved in 2.0 minutes.
# Processing user group 58:
# Saving data...
# Group 58 processed and saved in 2.0 minutes.
# Processing user group 59:
# Saving data...
# Group 59 processed and saved in 2.0 minutes.
# Processing user group 60:
# Saving data...
# Group 60 processed and saved in 2.0 minutes.
# Processing user group 61:
# Saving data...
# Group 61 processed and saved in 2.0 minutes.
# Processing user group 62:
# Saving data...
# Group 62 processed and saved in 2.0 minutes.
# Processing user group 63:
# Saving data...
# Group 63 processed and saved in 2.0 minutes.
# Processing user group 64:
# Saving data...
# Group 64 processed and saved in 2.0 minutes.
# Processing user group 65:
# Saving data...
# Group 65 processed and saved in 2.0 minutes.
# Processing user group 66:
# Saving data...
# Group 66 processed and saved in 2.0 minutes.
# Processing user group 67:
# Saving data...
# Group 67 processed and saved in 2.0 minutes.
# Processing user group 68:
# Saving data...
# Group 68 processed and saved in 2.0 minutes.
# Processing user group 69:
# Saving data...
# Group 69 processed and saved in 2.0 minutes.
# Processing user group 70:
# Saving data...
# Group 70 processed and saved in 2.0 minutes.
# Processing user group 71:
# Saving data...
# Group 71 processed and saved in 2.0 minutes.
# Processing user group 72:
# Saving data...
# Group 72 processed and saved in 2.0 minutes.
# Processing user group 73:
# Saving data...
# Group 73 processed and saved in 2.0 minutes.
# Processing user group 74:
# Saving data...
# Group 74 processed and saved in 2.0 minutes.
# Processing user group 75:
# Saving data...
# Group 75 processed and saved in 2.0 minutes.
# Processing user group 76:
# Saving data...
# Group 76 processed and saved in 2.0 minutes.
# Processing user group 77:
# Saving data...
# Group 77 processed and saved in 2.0 minutes.
# Processing user group 78:
# Saving data...
# Group 78 processed and saved in 2.0 minutes.
# Processing user group 79:
# Saving data...
# Group 79 processed and saved in 2.0 minutes.
# Processing user group 80:
# Saving data...
# Group 80 processed and saved in 2.0 minutes.
# Processing user group 81:
# Saving data...
# Group 81 processed and saved in 2.0 minutes.
# Processing user group 82:
# Saving data...
# Group 82 processed and saved in 2.0 minutes.
# Processing user group 83:
# Saving data...
# Group 83 processed and saved in 2.0 minutes.
# Processing user group 84:
# Saving data...
# Group 84 processed and saved in 2.0 minutes.
# Processing user group 85:
# Saving data...
# Group 85 processed and saved in 2.0 minutes.
# Processing user group 86:
# Saving data...
# Group 86 processed and saved in 2.0 minutes.
# Processing user group 87:
# Saving data...
# Group 87 processed and saved in 2.0 minutes.
# Processing user group 88:
# Saving data...
# Group 88 processed and saved in 2.0 minutes.
# Processing user group 89:
# Saving data...
# Group 89 processed and saved in 2.0 minutes.
# Processing user group 90:
# Saving data...
# Group 90 processed and saved in 2.0 minutes.
# Processing user group 91:
# Saving data...
# Group 91 processed and saved in 2.0 minutes.
# Processing user group 92:
# Saving data...
# Group 92 processed and saved in 2.0 minutes.
# Processing user group 93:
# Saving data...
# Group 93 processed and saved in 3.0 minutes.
# Processing user group 94:
# Saving data...
# Group 94 processed and saved in 2.0 minutes.
# Processing user group 95:
# Saving data...
# Group 95 processed and saved in 2.0 minutes.
# Processing user group 96:
# Saving data...
# Group 96 processed and saved in 2.0 minutes.
# Processing user group 97:
# Saving data...
# Group 97 processed and saved in 2.0 minutes.
# Processing user group 98:
# Saving data...
# Group 98 processed and saved in 2.0 minutes.
# Processing user group 99:
# Saving data...
# Group 99 processed and saved in 2.0 minutes.
